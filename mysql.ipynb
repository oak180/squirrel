# %%
# %load_ext sql

# %%
# %sql mysql://root:admin@localhost:3306/noaddr

# %%
# %%sql
# SELECT patient.patient_id, names.given_name, names.family_name, person.uuid
# FROM patient INNER JOIN person_name AS names INNER JOIN person
# ON patient.patient_id = names.person_id = person.person_id
# ORDER BY patient.patient_id ASC;
# Out:
#  * mysql://root:***@localhost:3306/noaddr
# 53 rows affected.
# [(7, 'Betty', 'Williams', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (8, 'Susan', 'Lopez', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (9, 'Barbara', 'Miller', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (10, 'Grace', 'Garcia', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (11, 'Mark', 'Smith', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (12, 'James', 'Martinez', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (13, 'Michael', 'Turner', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (14, 'Kevin', 'Brown', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (15, 'Joshua', 'Johnson', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (16, 'Emily', 'Hill', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (17, 'George', 'Anderson', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (18, 'Brian', 'Lopez', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
#  (19, 'Donald', 'Harris', '5f87c042-6814-11e8-923f-e9a88dcb533f'),
# ...

# %%
# %%sql
# SELECT person_attribute_type_id, name, searchable FROM person_attribute_type;
# Out:
#  * mysql://root:***@localhost:3306/noaddr
# 10 rows affected.
# [(1, 'Race', 0),
#  (2, 'Birthplace', 0),
#  (3, 'Citizenship', 0),
#  (4, "Mother's Name", 0),
#  (5, 'Civil Status', 0),
#  (6, 'Health District', 0),
#  (7, 'Health Center', 0),
#  (8, 'email', 1),
#  (9, 'Telephone Number', 0),
#  (10, 'Unknown patient', 0)]

# %%
# %%sql
# SELECT person.person_id, names.given_name, names.family_name, person.uuid
# FROM person INNER JOIN person_name AS names
# ON person.person_id = names.person_id
# WHERE person.uuid = '5f897a68-6814-11e8-923f-e9a88dcb533f';
# Out:
#  * mysql://root:***@localhost:3306/noaddr
# 0 rows affected.
# []

# %%
# %%sql
# SELECT person.person_id, names.given_name, names.family_name, person.uuid
# FROM person INNER JOIN person_name AS names
# ON person.person_id = names.person_id
# WHERE names.given_name = 'Super';
# Out:
#  * mysql://root:***@localhost:3306/noaddr
# 1 rows affected.
# [(1, 'Super', 'User', '5f87c042-6814-11e8-923f-e9a88dcb533f')]
